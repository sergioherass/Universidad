# %%
import matplotlib.pyplot as plt
import numpy as np

# Definir el radio de la circunferencia
r = 1.0

# Número de puntos
num_points = 50

# Calcular las coordenadas paramétricas de los puntos con un componente aleatorio
theta = np.linspace(0, 2*np.pi, num_points)
x = r * np.cos(theta) + 0.1 * np.random.normal(size=num_points)
y = r * np.sin(theta) + 0.1 * np.random.normal(size=num_points)

# Crear una lista de puntos
points = list(zip(x, y))

# Graficar los puntos
plt.plot(x, y, 'o', label='Circunferencia Aproximada')

# Configurar el aspecto de la gráfica
plt.axis('equal')  # Asegurar que los ejes tengan la misma escala
plt.title('Aproximación de una Circunferencia con 50 Puntos Desplazados')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.grid(True)

# Mostrar la gráfica
plt.show()

# Imprimir la lista de puntos
print("Lista de Puntos:")
for point in points:
    print(point)
# Out:
# Lista de Puntos:
# (1.052016750335992, 0.21683197679035315)
# (0.9531240484030392, 0.0660941747612647)
# (0.9105692268590312, 0.23292692737274134)
# (1.1095372366818, 0.3890455656527737)
# (1.0729336593061842, 0.5695998511443975)
# (0.8747787521182848, 0.42453513374024415)
# (0.8238842680751081, 0.7028558306167231)
# (0.4320097854504793, 0.8672171828362433)
# (0.4365095472674276, 0.777262514687422)
# (0.3508962762993225, 0.8178017835008218)
# (0.20514985272281572, 0.9362669168623654)
# (0.13876741907983223, 0.9113568653121543)
# (0.014779595834737386, 1.052491380339593)
# (-0.13052138485731368, 0.9216227974710608)
# (-0.3434666101295275, 0.979851296864128)
# (-0.3789288747667171, 0.8685917010321789)
# (-0.5896235058591214, 0.9352359124045722)
# (-0.5857712412988849, 0.8756480513567954)
# (-0.5450500217943621, 0.7868065632727194)
# (-0.9945956621199105, 0.5946455957422089)
# (-0.785694079171376, 0.6770472876463305)
# (-0.9050553960246348, 0.4803590858641925)
# ...
